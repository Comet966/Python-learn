# %% [markdown]
# #### 字符串

# %%
s1 = ('hello,'
      ' world!')
s2 = "你好，世界！❤️"
s3 = '''hello,
wonderful
world!'''
print(s1)
print(s2)
print(s3)
# Out:
# hello, world!
# 你好，世界！❤️
# hello,
# wonderful
# world!

# %%
#转义字符\
s1 = '\'hello world\' '
s2 = '\\hello world\\'
print(s1)
print(s2)

s1 = '\it \is \time \to \read \now'
#原始字符串使用r开头表示为原本的含义
s2 = r'\it \is \time \to \read \now'
print(s1)
print(s2)

s1 = '\141\142\143\x61\x62\x63'
#\八进制or十六进制表示字符
s2 = '\u9a86\u660a'
#\u+Unicode字符编码表示中文
print(s1)
print(s2)
# Out:
# 'hello world'
# \hello world\
# ead \is 	ime 	o
# ow
# \it \is \time \to \read \now
# abcabc
# 骆昊

# %%
s1 = '123456789'
#使用列表切片的方式处理字符串
s2 = s1[0:10:2]
print(s2)
#ord()方法得到字符对应编码
#字符字符串的比较本质是比较编码
s1 = 'boy'
s2 = 'bad'
print(s1 >= s2)
print(ord('o'),ord('a'))
#len()方法获得字符串的长度
print(len(s1))
#索引访问
print(s1[0], s1[-3])
print(s1[::-1])#倒序
#类似地
#find() 未找到返回-1
#index() 未找到报错ValueError
# 方法同样适用于字符串
#rfind()逆向查找
s1 = 'hello,world'
print(s1.rfind('o'))
# Out:
# 13579
# True
# 111 97
# 3
# b b
# yob
# 7

# %%
s1 = 'hello,world'
#判断开头结尾
print(s1.startswith('o'))
s1 = 'hello,world'
print(s1.endswith('d'))
s2 = 'abc123'
#判断是否是纯数字/字母/混合
print(s2.isdigit())
print(s2.isalpha())
print(s2.isalnum())
# Out:
# False
# True
# False
# False
# True

# %% [markdown]
# #### 居中 左/右对齐操作

# %%
s = 'hello,world'
print(s.center(20,'*'))
print(s.rjust(20))
print(s.ljust(20,'~'))
#用零填充指定长度
print('33'.zfill(5))
print('-33'.zfill(5))
# Out:
# ****hello,world*****
#          hello,world
# hello,world~~~~~~~~~
# 00033
# -0033

# %% [markdown]
# ##### 格式输出format方法
# 如果需要进一步控制格式化语法中变量值的形式，可以参照下面的表格来进行字符串格式化操作。
#
# | 变量值      | 占位符     | 格式化结果    | 说明 |
# | ----------- | ---------- | ------------- | ---- |
# | `3.1415926` | `{:.2f}`   | `'3.14'`      | 保留小数点后两位 |
# | `3.1415926` | `{:+.2f}`  | `'+3.14'`       | 带符号保留小数点后两位 |
# | `-1`        | `{:+.2f}`  | `'-1.00'` | 带符号保留小数点后两位 |
# | `3.1415926` | `{:.0f}`   | `'3'` | 不带小数 |
# | `123`       | `{:0>10d}` | `'0000000123'` | 左边补`0`，补够10位 |
# | `123`       | `{:x<10d}` | `'123xxxxxxx'` | 右边补`x` ，补够10位 |
# | `123`       | `{:>10d}`  | `'       123'` | 左边补空格，补够10位 |
# | `123`       | `{:<10d}` | `'123       '` | 右边补空格，补够10位 |
# | `123456789` | `{:,}`     | `'123,456,789'` | 逗号分隔格式 |
# | `0.123`     | `{:.2%}`   | `'12.30%'`    | 百分比格式 |
# | `123456789` | `{:.2e}`   | `'1.23e+08'`  | 科学计数法格式 |

# %%
a = 321
b = 123
print('%d * %d = %d' % (a, b, a * b))
print('{0} * {1} = {2}'.format(a, b, a * b))
print(f'{a} * {b} = {a * b}')
# Out:
# 321 * 123 = 39483
# 321 * 123 = 39483
# 321 * 123 = 39483

# %%
#修剪操作
s1 = '       hello,world      '
print(s1.strip())#修剪两边的空格
print(s1)
s2 = '~hello world~~~'
#左右侧修剪特定符号
print(s2.lstrip('~'))
print(s2.rstrip('~'))

#替换操作
print()
print(s1.replace('o','0'))
print(s1.replace('o','0',1))#只替换一个
# Out:
# hello,world
#        hello,world
# hello world~~~
# ~hello world
#
#        hell0,w0rld
#        hell0,world

# %%
#拆分与合并
s = 'I love you'
words = s.split()#默认按照空格进行拆分
print(words)#拆分成list
#合并
print('~'.join(words))
s = 'I#love#you#so#much'
words = s.split('#')
print(words)
words = s.split('#',2)#仅仅依据前两个'#'进行拆分
print(words)
# Out:
# ['I', 'love', 'you']
# I~love~you
# ['I', 'love', 'you', 'so', 'much']
# ['I', 'love', 'you#so#much']

# %% [markdown]
# #### 编码与解码

# %%
a = '中文'
b = a.encode('utf-8')
c = a.encode('gbk')
print(b)
print(c)
print(b.decode('utf-8'))
print(c.decode('gbk'))
# Out:
# b'\xe4\xb8\xad\xe6\x96\x87'
# b'\xd6\xd0\xce\xc4'
# 中文
# 中文

# %% [markdown]
# #### 常用数据结构:集合set
# 特点:无序性 互异性 确定性
# 底层代码使用哈希储存
# 注意集合元素必须是不可变类型以便确定哈希值

# %%
#使用构造器set()创造集合
#或者使用{}
set1 = {1,2,3,3,3,2}
print(set1)
set2 = {'banana', 'pitaya', 'apple', 'apple', 'banana', 'grape'}
print(set2)

set3 = set('hello')
print(set3)

set4 = set([1,2,2,3,3,3,2,1])#会去除重复元素
print(set4)

set5 = {num for num in range(1, 20) if num % 3 == 0 or num % 7 == 0}
print(set5)
# Out:
# {1, 2, 3}
# {'apple', 'grape', 'banana', 'pitaya'}
# {'h', 'e', 'l', 'o'}
# {1, 2, 3}
# {3, 6, 7, 9, 12, 14, 15, 18}

# %%
#遍历集合元素
set1 = {'Python', 'C++', 'Java', 'Kotlin', 'Swift'}
for elem in set1:
    print(elem)
#具有无序性输出顺序由储存顺序决定

#集合的运算
set1 = {11,12,13,14,15}
print(10 in set1)
print(15 in set1)
set2 = {'Python', 'Java', 'C++', 'Swift'}
print('Ruby' in set2)
print('Java' in set2)
# Out:
# C++
# Swift
# Java
# Kotlin
# Python
# False
# True
# False
# True

# %% [markdown]
# #### 二元运算
# 交 并 差 补

# %%
set1 = {1, 2, 3, 4, 5, 6, 7}
set2 = {2, 4, 6, 8, 10}
#交集
print(set1 & set2)
print(set1.intersection(set2))

#并集
print(set1 | set2)
print(set1.union(set2))

#差集
print(set1 - set2)
print(set1.difference(set2))

#对称差
#即并集-交集
print(set1^set2)
print(set1.symmetric_difference(set2))

print((set1|set2) - (set1&set2))
# Out:
# {2, 4, 6}
# {2, 4, 6}
# {1, 2, 3, 4, 5, 6, 7, 8, 10}
# {1, 2, 3, 4, 5, 6, 7, 8, 10}
# {1, 3, 5, 7}
# {1, 3, 5, 7}
# {1, 3, 5, 7, 8, 10}
# {1, 3, 5, 7, 8, 10}
# {1, 3, 5, 7, 8, 10}

# %% [markdown]
# #### 集合的逻辑运算

# %%
set1 = {1, 3, 5}
set2 = {1, 2, 3, 4, 5}
set3 = {5, 4, 3, 2, 1}

print(set1 < set2) #是否是真子集
print(set1 <= set2)#是否是子集
print(set2 < set3)
print(set2 > set3)
print(set2 == set3)#是否是相同集合

print(set1.issubset(set2))#是否子集
print(set2.issuperset(set1))#是否超集
# Out:
# True
# True
# False
# False
# True
# True
# True

# %% [markdown]
# #### 集合的方法

# %%
set1 = {1,10,100}
#添加元素
set1.add(1000)
set1.add(10000)
print(set1)

#删除
set1.discard(10)
if 100 in set1:
    set1.remove(100)
print(set1)
print(set1.pop())#随机删除一个元素并返回

#清空元素
set1.clear()
print(set1)
# Out:
# {1, 100, 1000, 10, 10000}
# {1, 1000, 10000}
# 1
# set()

# %%
#判断交集是否有相同元素
set1 = {'Java', 'Python', 'C++', 'Kotlin'}
set2 = {'Kotlin', 'Swift', 'Java', 'Dart'}
set3 = {'HTML', 'CSS', 'JavaScript'}
print(set1.isdisjoint(set2))  # False
print(set1.isdisjoint(set3))  # True
#等价表示
print(not bool(set1&set2))
print(not bool(set3&set2))
# Out:
# False
# True
# False
# True

# %% [markdown]
# #### 不可变集合frozenset

# %%
fset1 = frozenset({1,3,5,7})
fset2 = frozenset(range(1,6))

print(fset1)
print(fset2)

print(fset1 & fset2)
print(fset1 | fset2)
print(fset1 - fset2)
print(fset1 < fset2)
# Out:
# frozenset({1, 3, 5, 7})
# frozenset({1, 2, 3, 4, 5})
# frozenset({1, 3, 5})
# frozenset({1, 2, 3, 4, 5, 7})
# frozenset({7})
# False

# %% [markdown]
# #### 字典
# 键值对

# %%
xinhua = {
    '麓': '山脚下',
    '路': '道，往来通行的地方；方面，地区：南～货，外～货；种类：他俩是一～人',
    '蕗': '甘草的别名',
    '潞': '潞水，水名，即今山西省的浊漳河；潞江，水名，即云南省的怒江'
}

print(xinhua)
#类似其他数据结构也可以使用dict()构造器
person = dict(name='王大锤', age=55, height=168, weight=60, addr='成都市武侯区科华北路62号1栋101')
print(person)
# Out:
# {'麓': '山脚下', '路': '道，往来通行的地方；方面，地区：南～货，外～货；种类：他俩是一～人', '蕗': '甘草的别名', '潞': '潞水，水名，即今山西省的浊漳河；潞江，水名，即云南省的怒江'}
# {'name': '王大锤', 'age': 55, 'height': 168, 'weight': 60, 'addr': '成都市武侯区科华北路62号1栋101'}

# %%
#通过Python内置zip创建字典
items1 = dict(zip('ABCDE','12345'))
print(items1)
items2 = dict(zip('ABCDE', range(1, 10)))
print(items2)

#使用字典生成语法
items3 = {x:x **3 for x in range(1,6)}
print(items3)
print(len(items1))#返回长度
for key in items1:#对键值遍历
    print(key)
# Out:
# {'A': '1', 'B': '2', 'C': '3', 'D': '4', 'E': '5'}
# {'A': 1, 'B': 2, 'C': 3, 'D': 4, 'E': 5}
# {1: 1, 2: 8, 3: 27, 4: 64, 5: 125}
# 5
# A
# B
# C
# D
# E

# %%
person = {'name': '王大锤', 'age': 55, 'height': 168, 'weight': 60, 'addr': '成都市武侯区科华北路62号1栋101'}

#使用键值对字典进行索引
print(person['name'])

for key in person:
    print(f'{key}:\t{person[key]}')
# Out:
# 王大锤
# name:	王大锤
# age:	55
# height:	168
# weight:	60
# addr:	成都市武侯区科华北路62号1栋101

# %%
#get方法由键获取对应值
person = {'name': '王大锤', 'age': 25, 'height': 178, 'addr': '成都市武侯区科华北路62号1栋101'}

print(person.get('name'))
print(person.get('sex'))
# Out:
# 王大锤
# None

# %%
person = {'name': '王大锤', 'age': 25, 'height': 178}
print(person.keys())    # dict_keys(['name', 'age', 'height'])
print(person.values())  # dict_values(['王大锤', 25, 178])
print(person.items())   # dict_items([('name', '王大锤'), ('age', 25), ('height', 178)])
for key, value in person.items():#对person.items()进行解包然后传给key,value
    print(f'{key}:\t{value}')
# Out:
# dict_keys(['name', 'age', 'height'])
# dict_values(['王大锤', 25, 178])
# dict_items([('name', '王大锤'), ('age', 25), ('height', 178)])
# name:	王大锤
# age:	25
# height:	178

# %% [markdown]
# #### 字典之间的运算

# %%
person1 = {'name': '王大锤', 'age': 55, 'height': 178}
person2 = {'age': 25, 'addr': '成都市武侯区科华北路62号1栋101'}

person1.update(person2)
#等效表达|
person1 |= person2
print(person1)#字典之间的合并update()

#删除元素
print(person1.pop('age'))#弹出并返回弹出的值
print(person1.popitem())
person1.clear()
print(person1)

#del关键字删除
del person2['age']
print(person2)
# Out:
# {'name': '王大锤', 'age': 25, 'height': 178, 'addr': '成都市武侯区科华北路62号1栋101'}
# 25
# ('addr', '成都市武侯区科华北路62号1栋101')
# {}
# {'addr': '成都市武侯区科华北路62号1栋101'}

# %% [markdown]
# #### 字典的应用

# %%
sentence = input('输入一段话:')
counter = {}
for ch in sentence:
    if 'A' <= ch <= 'Z' or 'a' <= ch <= 'z':
        counter[ch] = counter.get(ch,0) + 1#使用get()方法访问字典避免报错和初始化
sorted_keys = sorted(counter,key = counter.get,reverse = True)
for key in sorted_keys:
    print(f'{key}出现了{counter[key]}次')
# Out:
# d出现了3次
# s出现了3次
# j出现了2次
# f出现了2次
# o出现了1次
# i出现了1次

# %%
stocks = {
    'AAPL': 191.88,
    'GOOG': 1186.96,
    'IBM': 149.24,
    'ORCL': 48.44,
    'ACN': 166.89,
    'FB': 208.09,
    'SYMC': 21.29
}
stocks2 = {key: value for key, value in stocks.items() if value > 100}
print(stocks2)
# Out:
# {'AAPL': 191.88, 'GOOG': 1186.96, 'IBM': 149.24, 'ACN': 166.89, 'FB': 208.09}

# %% [markdown]
# #### 函数与模块

# %%
from math import factorial

def fac(num):
    result = 1
    for n in range(2,num+1):
        result *= n
    return result

m = int(input('m = '))
n = int(input('n = '))
print(factorial(m)//factorial(n)//factorial(m-n))
# Out:
# 10

# %%
#通过as关键字修改方法的名字
from math import factorial as f

print(f(5))
# Out:
# 120

# %%
#含有默认参数的函数
from random import randrange


# 定义摇色子的函数
# 函数的自变量（参数）n表示色子的个数，默认值为2
# 函数的因变量（返回值）表示摇n颗色子得到的点数
def roll_dice(n=2):
    total = 0
    for _ in range(n):
        total += randrange(1, 7)
    return total


# 如果没有指定参数，那么n使用默认值2，表示摇两颗色子
print(roll_dice())
# 传入参数3，变量n被赋值为3，表示摇三颗色子获得点数
print(roll_dice(3))
# Out:
# 8
# 8

# %%
def add(a=0, b=0, c=0):
    """三个数相加求和"""
    return a + b + c


# 调用add函数，没有传入参数，那么a、b、c都使用默认值0
print(add())         # 0
# 调用add函数，传入一个参数，该参数赋值给变量a, 变量b和c使用默认值0
print(add(1))        # 1
# 调用add函数，传入两个参数，分别赋值给变量a和b，变量c使用默认值0
print(add(1, 2))     # 3
# 调用add函数，传入三个参数，分别赋值给a、b、c三个变量
print(add(1, 2, 3))  # 6

# %% [markdown]
# 注意带默认参数的函数必须放在不带默认参数的函数之后
# #### 可变参数函数

# %%
#使用*表达式
def add(*args):
    total = 0
    for val in args:
        if type(val) in (int,float):
            #使用元组的in语法对val进行类型检查
            total += val
    return total

print(add(1,2))
print(add(1,2,3.22,'abcd'))
# Out:
# 3
# 6.220000000000001

# %%
#**当要传入的参数的参数名参数个数参数值都不确定时
def foo(*args,**kwargs):
    print(args)
    print(kwargs)

foo(3,3.2,True,name = '123',age = '22')
# Out:
# (3, 3.2, True)
# {'name': '123', 'age': '22'}

# %%
#函数名冲突时
def foo():
    print('hello, world!')


def foo():
    print('goodbye, world!')


foo()  # 大家猜猜调用foo函数会输出什么
# Out:
# goodbye, world!

# %% [markdown]
# #### 使用模块管理函数
# 导入函数: from 模块名 import 函数名 as name
# 模块别名: import 模块名 as name
# 或者直接在main之内使用 模块名.函数名 调用函数

# %% [markdown]
# #### 标准库中的函数
# 不需要导入可以直接调用
# | 函数    | 说明                                                         |
# | ------- | ------------------------------------------------------------ |
# | `abs`   | 返回一个数的绝对值，例如：`abs(-1.3)`会返回`1.3`。           |
# | `bin`   | 把一个整数转换成以`'0b'`开头的二进制字符串，例如：`bin(123)`会返回`'0b1111011'`。 |
# | `chr`   | 将Unicode编码转换成对应的字符，例如：`chr(8364)`会返回`'€'`。 |
# | `hex`   | 将一个整数转换成以`'0x'`开头的十六进制字符串，例如：`hex(123)`会返回`'0x7b'`。 |
# | `input` | 从输入中读取一行，返回读到的字符串。                         |
# | `len`   | 获取字符串、列表等的长度。                                   |
# | `max`   | 返回多个参数或一个可迭代对象中的最大值，例如：`max(12, 95, 37)`会返回`95`。 |
# | `min`   | 返回多个参数或一个可迭代对象中的最小值，例如：`min(12, 95, 37)`会返回`12`。 |
# | `oct`   | 把一个整数转换成以`'0o'`开头的八进制字符串，例如：`oct(123)`会返回`'0o173'`。 |
# | `open`  | 打开一个文件并返回文件对象。                                 |
# | `ord`   | 将字符转换成对应的Unicode编码，例如：`ord('€')`会返回`8364`。 |
# | `pow`   | 求幂运算，例如：`pow(2, 3)`会返回`8`；`pow(2, 0.5)`会返回`1.4142135623730951`。 |
# | `print` | 打印输出。                                                   |
# | `range` | 构造一个范围序列，例如：`range(100)`会产生`0`到`99`的整数序列。 |
# | `round` | 按照指定的精度对数值进行四舍五入，例如：`round(1.23456, 4)`会返回`1.2346`。 |
# | `sum`   | 对一个序列中的项从左到右进行求和运算，例如：`sum(range(1, 101))`会返回`5050`。 |
# | `type`  | 返回对象的类型，例如：`type(10)`会返回`int`；而` type('hello')`会返回`str`。 |

# %%
#函数的应用

#随机验证码
import random
import string

ALL_CHARS = string.digits + string.ascii_letters

def generate_code(*,code_len=4):
    """
    生成指定长度验证码
    :param code_len: 验证码长度
    :return:  由大小写英文字母和数字构成的随机验证码字符串
    """
    return ''.join(random.choices(ALL_CHARS,k=code_len))


print(generate_code())
# Out:
# xcn7

# %% [markdown]
# 在参数后使用:来标注参数类型,函数名后 :前使用->标注返回值类型

# %%
#判断素数
def is_prime(num: int) -> bool:
    """
    判断一个正整数是不是质数
    :param num: 大于1的正整数
    :return: 如果num是质数返回True否则返回False
    """
    for i in range(2,int(num**0.5)+1):
        if num%i == 0:
            return False
    return True

# %%
#最小公约数和最小公倍数
def lcm(x:int, y:int)->int:
    """求最小公倍数"""
    #利用lcm和gcd的关系
    return x*y // gcd(x,y)

def gcd(x:int, y:int)->int:
    """求最大公约数"""
    #欧几里得算法
    while y % x != 0:
        x ,y = y % x,x
    return x

# %%
#数据统计
def ptp(data):
    """极差"""
    return max(data) - min(data)

def mean(data):
    """算数平均"""
    return sum(data)/len(data)

def median(data):
    """中位数"""
    temp,size = sorted(data) , len(data)
    if size % 2 != 0:
        return temp[size/2]
    else:
        return mean(temp[size//2-1:size//2+1])

def var(data,ddof=1):
    """方差"""
    x_bar = mean(data)
    temp = [(num - x_bar)**2 for num in data]
    return sum(temp)/(len(temp)-ddof)

def std(data,ddof=1):
    """标准差"""
    return var(data,ddof)**0.5

def cv(data,ddof=1):
    """变异系数"""
    return std(data,ddof)/mean(data)

def describe(data):
    """输出描述性统计信息"""
    print(f'均值:{mean(data)}')
    print(f'中位数:{median(data)}')
    print(f'极差:{ptp(data)}')
    print(f'标准差:{std(data)}')
    print(f'方差:{var(data,ddof=1)}')
    print(f'变异系数:{cv(data,ddof=1)}')

# %%
#双色球随机选号
import random

RED_BALLS = [i for i in range(1,34)]
BLUE_BALLS = [i for i in range(1,17)]

def choose():
    """
    生成一组随机号码
    :return: 保存随机号码的列表
    """
    selected_balls = random.sample(RED_BALLS,6)
    selected_balls.sort()
    selected_balls.append(random.choice(BLUE_BALLS))
    return selected_balls

def display(balls):
    """
    格式化输出一组号码
    :param balls: 保存的随机号码列表
    """
    for ball in balls[:-1]:
        print(f'\033[031m{ball:0>2d}\03[0m',end='')
    print(f'\033[\034m{balls[-1]:0>2d}\033[0m')

n = int(input('生成几注号码:'))
for _ in range(n):
    display(choose())
# Out:
# 031019252632[m14
